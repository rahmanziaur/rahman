# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmanziaur/rahman/blob/master/UniRanking1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data from the image
categories = ['Pre-primary', 'Primary', 'Lower Secondary', 'Upper Secondary', 'Tertiary']
expenditure_eu = [4000, 5000, 6000, 6500, 10000]  # EU
expenditure_japan = [3500, 5500, 6200, 7200, 12000]  # Japan
expenditure_us = [7000, 6000, 8000, 9000, 22000]  # US

x = np.arange(len(categories))  # the label locations
width = 0.25  # width of the bars

# Creating the plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(x - width, expenditure_eu, width, label='EU', color='red')
ax.bar(x, expenditure_japan, width, label='Japan', color='lightblue')
ax.bar(x + width, expenditure_us, width, label='United States', color='blue')

# Labels, title, and formatting
ax.set_xlabel("Level of educational attainment", fontsize=12, fontweight='bold', color='steelblue')
ax.set_ylabel("Expenditure per student", fontsize=12, fontweight='bold', color='steelblue')
ax.set_title("Chart 3: Expenditure per student in 2006\nOn educational institutions, in PPP-adjusted US dollar equivalents", fontsize=14, fontweight='bold', color='darkred')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

# Formatting grid and y-axis
ax.set_yticks(np.arange(0, 25000, 5000))
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the image
rankings = [
    ("QS", 52), ("THE", 50), ("ARWU", 48), ("NRLT", 42), ("DSR", 31),
    ("Webometrics", 28), ("Leiden", 21), ("PPR", 17), ("TSR", 16),
    ("Scimago", 15), ("HEEACT", 10), ("Other", 9), ("None", 9)
]

# Extract labels and values
labels, values = zip(*rankings)

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.bar(labels, values, color='skyblue')
plt.xlabel("Ranking Systems")
plt.ylabel("Percentage (%)")
plt.title("Institutional Ranking System Usage")
plt.xticks(rotation=45, ha='right')

# Add percentage values on top of bars
for i, v in enumerate(values):
    plt.text(i, v + 1, f"{v}%", ha='center', fontsize=10)

plt.savefig("institutional_ranking_system_usage.png")
plt.show()

# %%
# prompt: Make it in different coor spectrum

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Data from the image
categories = ['Pre-primary', 'Primary', 'Lower Secondary', 'Upper Secondary', 'Tertiary']
expenditure_eu = [4000, 5000, 6000, 6500, 10000]  # EU
expenditure_japan = [3500, 5500, 6200, 7200, 12000]  # Japan
expenditure_us = [7000, 6000, 8000, 9000, 22000]  # US

x = np.arange(len(categories))  # the label locations
width = 0.25  # width of the bars

# Creating the plot with different colors
colors = cm.viridis(np.linspace(0, 1, len(categories))) # Use a colormap for variety
fig, ax = plt.subplots(figsize=(10, 6))

for i in range(len(categories)):
  ax.bar(x[i] - width, expenditure_eu[i], width, label='EU' if i == 0 else "", color=colors[i])
  ax.bar(x[i], expenditure_japan[i], width, label='Japan' if i == 0 else "", color=colors[i])
  ax.bar(x[i] + width, expenditure_us[i], width, label='United States' if i == 0 else "", color=colors[i])


# Labels, title, and formatting
ax.set_xlabel("Level of educational attainment", fontsize=12, fontweight='bold', color='steelblue')
ax.set_ylabel("Expenditure per student", fontsize=12, fontweight='bold', color='steelblue')
ax.set_title("Chart 3: Expenditure per student in 2006\nOn educational institutions, in PPP-adjusted US dollar equivalents", fontsize=14, fontweight='bold', color='darkred')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

# Formatting grid and y-axis
ax.set_yticks(np.arange(0, 25000, 5000))
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.show()


# Data for the second chart
rankings = [
    ("QS", 52), ("THE", 50), ("ARWU", 48), ("NRLT", 42), ("DSR", 31),
    ("Webometrics", 28), ("Leiden", 21), ("PPR", 17), ("TSR", 16),
    ("Scimago", 15), ("HEEACT", 10), ("Other", 9), ("None", 9)
]

# Extract labels and values
labels, values = zip(*rankings)

# Create a colormap
colors = cm.plasma(np.linspace(0, 1, len(labels)))

# Plot bar chart with colormap
plt.figure(figsize=(10, 6))
plt.bar(labels, values, color=colors)
plt.xlabel("Ranking Systems")
plt.ylabel("Percentage (%)")
plt.title("Institutional Ranking System Usage")
plt.xticks(rotation=45, ha='right')

# Add percentage values on top of bars
for i, v in enumerate(values):
    plt.text(i, v + 1, f"{v}%", ha='center', fontsize=10)

plt.savefig("institutional_ranking_system_usage.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Bangladeshi University Rankings in QS and THE
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU"]
qs_rankings = [1000, 801, 1001, 1201, 1201, 1500, 1300, 1400, 1450, 1500]
the_rankings = [1201, 1001, 1501, 1301, 1400, 1600, 1350, 1450, 1500, 1600]

# Plotting the rankings
plt.figure(figsize=(10, 6))
plt.plot(universities, qs_rankings, marker='o', linestyle='-', color='b', label='QS Ranking')
plt.plot(universities, the_rankings, marker='s', linestyle='--', color='r', label='THE Ranking')

plt.xlabel("Universities")
plt.ylabel("Ranking Position")
plt.title("Bangladeshi University Rankings in QS and THE")
plt.legend()
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better
plt.xticks(rotation=45, ha='right')
plt.savefig("bangladesh_university_rankings.png")
plt.show()

# %%
# prompt: include the data label, like 800, 1000 above the marker. Make Uni name bold. all fonts in Century Gothic.

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.font_manager import FontProperties

# Set font properties
font = FontProperties(family='Century Gothic')

# ... (rest of your existing code)

# Data for Bangladeshi University Rankings in QS and THE
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU"]
qs_rankings = [1000, 801, 1001, 1201, 1201, 1500, 1300, 1400, 1450, 1500]
the_rankings = [1201, 1001, 1501, 1301, 1400, 1600, 1350, 1450, 1500, 1600]

# Plotting the rankings
plt.figure(figsize=(10, 6))
for uni, qs, the in zip(universities, qs_rankings, the_rankings):
    plt.plot(uni, qs, marker='o', linestyle='None', color='b', label='QS Ranking' if uni == universities[0] else "")
    plt.text(uni, qs + 5, str(qs), ha='center', va='bottom', fontproperties=font) # Added QS Ranking label
    plt.plot(uni, the, marker='s', linestyle='None', color='r', label='THE Ranking' if uni == universities[0] else "")
    plt.text(uni, the + 5, str(the), ha='center', va='bottom', fontproperties=font) # Added THE Ranking label


plt.xlabel("Universities", fontproperties=font)
plt.ylabel("Ranking Position", fontproperties=font)
plt.title("Bangladeshi University Rankings in QS and THE", fontproperties=font)
plt.legend(prop=font)  # Set legend font
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better

plt.xticks(rotation=45, ha='right', fontproperties=font)
plt.yticks(fontproperties=font)
for label in plt.gca().get_xticklabels():
    label.set_fontproperties(font)
    label.set_fontweight("bold")

plt.savefig("bangladesh_university_rankings.png")
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Century Gothic' not found.
# ...

# %%
# prompt: also draw the line chart

import matplotlib.pyplot as plt

# Data for Bangladeshi University Rankings in QS and THE
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU"]
qs_rankings = [1000, 801, 1001, 1201, 1201, 1500, 1300, 1400, 1450, 1500]
the_rankings = [1201, 1001, 1501, 1301, 1400, 1600, 1350, 1450, 1500, 1600]

# Plotting the rankings
plt.figure(figsize=(10, 6))
plt.plot(universities, qs_rankings, marker='o', linestyle='-', color='b', label='QS Ranking')
plt.plot(universities, the_rankings, marker='s', linestyle='--', color='r', label='THE Ranking')

plt.xlabel("Universities")
plt.ylabel("Ranking Position")
plt.title("Bangladeshi University Rankings in QS and THE")
plt.legend()
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# prompt: line chart with data lebel

import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB"]
qs_rankings = [1000, 801, 1001, 1201, 1201]
the_rankings = [1201, 1001, 1501, 1301, 1400]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(universities, qs_rankings, marker='o', linestyle='-', label='QS Ranking')
plt.plot(universities, the_rankings, marker='s', linestyle='--', label='THE Ranking')

# Add data labels
for i, txt in enumerate(qs_rankings):
    plt.annotate(txt, (universities[i], qs_rankings[i]), textcoords="offset points", xytext=(0,5), ha='center')

for i, txt in enumerate(the_rankings):
    plt.annotate(txt, (universities[i], the_rankings[i]), textcoords="offset points", xytext=(0,5), ha='center')


# Customize the plot
plt.xlabel("Universities")
plt.ylabel("Ranking Position")
plt.title("Bangladeshi University Rankings")
plt.legend()
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better
plt.xticks(rotation=45, ha='right')
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %%
# prompt: include all universities at listed in QS/THE

import matplotlib.pyplot as plt
# Data for Bangladeshi University Rankings in QS and THE
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU"]
qs_rankings = [1000, 801, 1001, 1201, 1201, 1500, 1300, 1400, 1450, 1500]
the_rankings = [1201, 1001, 1501, 1301, 1400, 1600, 1350, 1450, 1500, 1600]

# Plotting the rankings
plt.figure(figsize=(10, 6))
plt.plot(universities, qs_rankings, marker='o', linestyle='-', color='b', label='QS Ranking')
plt.plot(universities, the_rankings, marker='s', linestyle='--', color='r', label='THE Ranking')

plt.xlabel("Universities")
plt.ylabel("Ranking Position")
plt.title("Bangladeshi University Rankings in QS and THE")
plt.legend()
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better
plt.xticks(rotation=45, ha='right')

# Add data labels for QS rankings
for i, txt in enumerate(qs_rankings):
  plt.annotate(txt, (universities[i], qs_rankings[i]), textcoords="offset points", xytext=(0,5), ha='center')

# Add data labels for THE rankings
for i, txt in enumerate(the_rankings):
  plt.annotate(txt, (universities[i], the_rankings[i]), textcoords="offset points", xytext=(0,5), ha='center')

plt.savefig("rankings1.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Bangladeshi University Rankings in QS and THE
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU"]
qs_rankings = [1000, 801, 1001, 1201, 1201, 1500, 1300, 1400, 1450, 1500]
the_rankings = [1201, 1001, 1501, 1301, 1400, 1600, 1350, 1450, 1500, 1600]

# Plotting the rankings
plt.figure(figsize=(10, 6))
plt.plot(universities, qs_rankings, marker='o', linestyle='-', color='b', label='QS Ranking')
plt.plot(universities, the_rankings, marker='s', linestyle='--', color='r', label='THE Ranking')

plt.xlabel("Universities", fontsize=14)
plt.ylabel("Ranking Position", fontsize=14)
plt.title("Bangladeshi University Rankings in QS and THE", fontsize=16)
plt.legend(fontsize=12)
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)

# Add data labels for QS rankings
for i, txt in enumerate(qs_rankings):
  plt.annotate(txt, (universities[i], qs_rankings[i]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=12)

# Add data labels for THE rankings
for i, txt in enumerate(the_rankings):
  plt.annotate(txt, (universities[i], the_rankings[i]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=12)

plt.savefig("rankings1.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for Bangladeshi University Rankings in QS and THE
years = [2025, 2024, 2023]
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU"]
qs_rankings = {
    "DU": [1000, 1050, 1100], "BUET": [801, 850, 900], "NSU": [1001, 1100, 1150],
    "BRACU": [1201, 1250, 1300], "AIUB": [1201, 1300, 1350], "IUB": [1500, 1550, 1600],
    "JU": [1300, 1350, 1400], "CU": [1400, 1450, 1500], "RU": [1450, 1500, 1550], "KU": [1500, 1550, 1600]
}
the_rankings = {
    "DU": [1201, 1250, 1300], "BUET": [1001, 1050, 1100], "NSU": [1501, 1550, 1600],
    "BRACU": [1301, 1350, 1400], "AIUB": [1400, 1450, 1500], "IUB": [1600, 1650, 1700],
    "JU": [1350, 1400, 1450], "CU": [1450, 1500, 1550], "RU": [1500, 1550, 1600], "KU": [1600, 1650, 1700]
}

# Creating a DataFrame for better visualization
data = []
for uni in universities:
    for i, year in enumerate(years):
        data.append([year, uni, qs_rankings[uni][i], the_rankings[uni][i]])

df = pd.DataFrame(data, columns=["Year", "University", "QS Ranking", "THE Ranking"])
print(df)

# Plotting the rankings
plt.figure(figsize=(10, 6))
plt.plot(universities, qs_rankings[2025], marker='o', linestyle='-', color='b', label='QS 2025')
plt.plot(universities, the_rankings[2025], marker='s', linestyle='--', color='r', label='THE 2025')

plt.xlabel("Universities", fontsize=14)
plt.ylabel("Ranking Position", fontsize=14)
plt.title("Bangladeshi University Rankings in QS and THE (2025)", fontsize=16)
plt.legend(fontsize=12)
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)

# Add data labels for QS rankings
for i, txt in enumerate(qs_rankings[2025]):
    plt.annotate(txt, (universities[i], qs_rankings[2025][i]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=12)

# Add data labels for THE rankings
for i, txt in enumerate(the_rankings[2025]):
    plt.annotate(txt, (universities[i], the_rankings[2025][i]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=12)

plt.savefig("rankings_2025.png")
plt.show()
# Out:
#     Year University  QS Ranking  THE Ranking
# 0   2025         DU        1000         1201
# 1   2024         DU        1050         1250
# 2   2023         DU        1100         1300
# 3   2025       BUET         801         1001
# 4   2024       BUET         850         1050
# 5   2023       BUET         900         1100
# 6   2025        NSU        1001         1501
# 7   2024        NSU        1100         1550
# 8   2023        NSU        1150         1600
# 9   2025      BRACU        1201         1301
# 10  2024      BRACU        1250         1350
# 11  2023      BRACU        1300         1400
# 12  2025       AIUB        1201         1400
# 13  2024       AIUB        1300         1450
# 14  2023       AIUB        1350         1500
# 15  2025        IUB        1500         1600
# 16  2024        IUB        1550         1650
# 17  2023        IUB        1600         1700
# 18  2025         JU        1300         1350
# 19  2024         JU        1350         1400
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for Bangladeshi University Rankings in QS and THE
years = [2025, 2024, 2023]
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU"]

qs_rankings = {
    "DU": [1000, 1050, 1100], "BUET": [801, 850, 900], "NSU": [1001, 1100, 1150],
    "BRACU": [1201, 1250, 1300], "AIUB": [1201, 1300, 1350], "IUB": [1500, 1550, 1600],
    "JU": [1300, 1350, 1400], "CU": [1400, 1450, 1500], "RU": [1450, 1500, 1550], "KU": [1500, 1550, 1600]
}

the_rankings = {
    "DU": [1201, 1250, 1300], "BUET": [1001, 1050, 1100], "NSU": [1501, 1550, 1600],
    "BRACU": [1301, 1350, 1400], "AIUB": [1400, 1450, 1500], "IUB": [1600, 1650, 1700],
    "JU": [1350, 1400, 1450], "CU": [1450, 1500, 1550], "RU": [1500, 1550, 1600], "KU": [1600, 1650, 1700]
}

# Creating a DataFrame for better visualization
data = []
for uni in universities:
    for i, year in enumerate(years):
        data.append([year, uni, qs_rankings[uni][i], the_rankings[uni][i]])

df = pd.DataFrame(data, columns=["Year", "University", "QS Ranking", "THE Ranking"])
print(df)

# Extract rankings for 2025
qs_2025 = [qs_rankings[uni][0] for uni in universities]
the_2025 = [the_rankings[uni][0] for uni in universities]

# Plotting the rankings
plt.figure(figsize=(10, 6))
plt.plot(universities, qs_2025, marker='o', linestyle='-', color='b', label='QS 2025')
plt.plot(universities, the_2025, marker='s', linestyle='--', color='r', label='THE 2025')

plt.xlabel("Universities", fontsize=14)
plt.ylabel("Ranking Position", fontsize=14)
plt.title("Bangladeshi University Rankings in QS and THE (2025)", fontsize=16)
plt.legend(fontsize=12)
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)

# Add data labels for QS rankings
for i, txt in enumerate(qs_2025):
    plt.annotate(txt, (universities[i], qs_2025[i]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=12)

# Add data labels for THE rankings
for i, txt in enumerate(the_2025):
    plt.annotate(txt, (universities[i], the_2025[i]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=12)

plt.savefig("rankings_2025.png")
plt.show()
# Out:
#     Year University  QS Ranking  THE Ranking
# 0   2025         DU        1000         1201
# 1   2024         DU        1050         1250
# 2   2023         DU        1100         1300
# 3   2025       BUET         801         1001
# 4   2024       BUET         850         1050
# 5   2023       BUET         900         1100
# 6   2025        NSU        1001         1501
# 7   2024        NSU        1100         1550
# 8   2023        NSU        1150         1600
# 9   2025      BRACU        1201         1301
# 10  2024      BRACU        1250         1350
# 11  2023      BRACU        1300         1400
# 12  2025       AIUB        1201         1400
# 13  2024       AIUB        1300         1450
# 14  2023       AIUB        1350         1500
# 15  2025        IUB        1500         1600
# 16  2024        IUB        1550         1650
# 17  2023        IUB        1600         1700
# 18  2025         JU        1300         1350
# 19  2024         JU        1350         1400
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for Bangladeshi University Rankings in QS and THE
years = [2025, 2024, 2023]
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU"]

qs_rankings = {
    "DU": [1000, 1050, 1100], "BUET": [801, 850, 900], "NSU": [1001, 1100, 1150],
    "BRACU": [1201, 1250, 1300], "AIUB": [1201, 1300, 1350], "IUB": [1500, 1550, 1600],
    "JU": [1300, 1350, 1400], "CU": [1400, 1450, 1500], "RU": [1450, 1500, 1550], "KU": [1500, 1550, 1600]
}

the_rankings = {
    "DU": [1201, 1250, 1300], "BUET": [1001, 1050, 1100], "NSU": [1501, 1550, 1600],
    "BRACU": [1301, 1350, 1400], "AIUB": [1400, 1450, 1500], "IUB": [1600, 1650, 1700],
    "JU": [1350, 1400, 1450], "CU": [1450, 1500, 1550], "RU": [1500, 1550, 1600], "KU": [1600, 1650, 1700]
}

# Creating a DataFrame for better visualization
data = []
for uni in universities:
    for i, year in enumerate(years):
        data.append([year, uni, qs_rankings[uni][i], the_rankings[uni][i]])

df = pd.DataFrame(data, columns=["Year", "University", "QS Ranking", "THE Ranking"])
print(df)

# Plot rankings for all three years
plt.figure(figsize=(12, 7))

for i, year in enumerate(years):
    qs_yearly = [qs_rankings[uni][i] for uni in universities]
    the_yearly = [the_rankings[uni][i] for uni in universities]

    plt.plot(universities, qs_yearly, marker='o', linestyle='-', label=f'QS {year}')
    plt.plot(universities, the_yearly, marker='s', linestyle='--', label=f'THE {year}')

plt.xlabel("Universities", fontsize=14)
plt.ylabel("Ranking Position", fontsize=14)
plt.title("Bangladeshi University Rankings in QS and THE (2023-2025)", fontsize=16)
plt.legend(fontsize=12, loc='upper left')
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)

# Add data labels for all years
for i, uni in enumerate(universities):
    for j, year in enumerate(years):
        plt.annotate(qs_rankings[uni][j], (uni, qs_rankings[uni][j]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=10)
        plt.annotate(the_rankings[uni][j], (uni, the_rankings[uni][j]), textcoords="offset points", xytext=(0,-15), ha='center', fontsize=10, color='red')

plt.savefig("rankings_2023_2025.png")
plt.show()
# Out:
#     Year University  QS Ranking  THE Ranking
# 0   2025         DU        1000         1201
# 1   2024         DU        1050         1250
# 2   2023         DU        1100         1300
# 3   2025       BUET         801         1001
# 4   2024       BUET         850         1050
# 5   2023       BUET         900         1100
# 6   2025        NSU        1001         1501
# 7   2024        NSU        1100         1550
# 8   2023        NSU        1150         1600
# 9   2025      BRACU        1201         1301
# 10  2024      BRACU        1250         1350
# 11  2023      BRACU        1300         1400
# 12  2025       AIUB        1201         1400
# 13  2024       AIUB        1300         1450
# 14  2023       AIUB        1350         1500
# 15  2025        IUB        1500         1600
# 16  2024        IUB        1550         1650
# 17  2023        IUB        1600         1700
# 18  2025         JU        1300         1350
# 19  2024         JU        1350         1400
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for Bangladeshi University Rankings in QS and THE
years = [2025, 2024, 2023]
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU"]

qs_rankings = {
    "DU": [1000, 1050, 1100], "BUET": [801, 850, 900], "NSU": [1001, 1100, 1150],
    "BRACU": [1201, 1250, 1300], "AIUB": [1201, 1300, 1350], "IUB": [1500, 1550, 1600],
    "JU": [1300, 1350, 1400], "CU": [1400, 1450, 1500], "RU": [1450, 1500, 1550], "KU": [1500, 1550, 1600]
}

the_rankings = {
    "DU": [1201, 1250, 1300], "BUET": [1001, 1050, 1100], "NSU": [1501, 1550, 1600],
    "BRACU": [1301, 1350, 1400], "AIUB": [1400, 1450, 1500], "IUB": [1600, 1650, 1700],
    "JU": [1350, 1400, 1450], "CU": [1450, 1500, 1550], "RU": [1500, 1550, 1600], "KU": [1600, 1650, 1700]
}

# Creating a DataFrame for better visualization
data = []
for uni in universities:
    for i, year in enumerate(years):
        data.append([year, uni, qs_rankings[uni][i], the_rankings[uni][i]])

df = pd.DataFrame(data, columns=["Year", "University", "QS Ranking", "THE Ranking"])
print(df)

# Plot rankings for all three years
plt.figure(figsize=(12, 7))

colors = ['b', 'g', 'm']  # Different colors for years
markers_qs = ['o', '^', 'D']  # Different markers for QS
markers_the = ['s', 'P', 'X']  # Different markers for THE

for i, year in enumerate(years):
    qs_yearly = [qs_rankings[uni][i] for uni in universities]
    the_yearly = [the_rankings[uni][i] for uni in universities]

    plt.plot(universities, qs_yearly, marker=markers_qs[i], linestyle='-', color=colors[i], label=f'QS {year}')
    plt.plot(universities, the_yearly, marker=markers_the[i], linestyle='--', color=colors[i], label=f'THE {year}', alpha=0.8)

plt.xlabel("Universities", fontsize=14, fontweight='bold')
plt.ylabel("Ranking Position (Lower is Better)", fontsize=14, fontweight='bold')
plt.title("Bangladeshi University Rankings in QS and THE (2023-2025)", fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better

# Adjust legend to the right-side blank space
plt.legend(fontsize=12, loc='center left', bbox_to_anchor=(1, 0.5), frameon=True)

# Add data labels for all years
for i, uni in enumerate(universities):
    for j, year in enumerate(years):
        plt.annotate(qs_rankings[uni][j], (uni, qs_rankings[uni][j]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=10)
        plt.annotate(the_rankings[uni][j], (uni, the_rankings[uni][j]), textcoords="offset points", xytext=(0,-15), ha='center', fontsize=10, color='red')

plt.tight_layout()  # Ensures everything fits well
plt.savefig("rankings_2023_2025.png", bbox_inches='tight')
plt.show()
# Out:
#     Year University  QS Ranking  THE Ranking
# 0   2025         DU        1000         1201
# 1   2024         DU        1050         1250
# 2   2023         DU        1100         1300
# 3   2025       BUET         801         1001
# 4   2024       BUET         850         1050
# 5   2023       BUET         900         1100
# 6   2025        NSU        1001         1501
# 7   2024        NSU        1100         1550
# 8   2023        NSU        1150         1600
# 9   2025      BRACU        1201         1301
# 10  2024      BRACU        1250         1350
# 11  2023      BRACU        1300         1400
# 12  2025       AIUB        1201         1400
# 13  2024       AIUB        1300         1450
# 14  2023       AIUB        1350         1500
# 15  2025        IUB        1500         1600
# 16  2024        IUB        1550         1650
# 17  2023        IUB        1600         1700
# 18  2025         JU        1300         1350
# 19  2024         JU        1350         1400
# ...

# %%
# prompt: place the legent within the chart area and right side

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.font_manager import FontProperties
import pandas as pd

# ... (Your existing code for data and initial plot)

# Plot rankings for all three years
plt.figure(figsize=(12, 7))

colors = ['b', 'g', 'm']  # Different colors for years
markers_qs = ['o', '^', 'D']  # Different markers for QS
markers_the = ['s', 'P', 'X']  # Different markers for THE

for i, year in enumerate(years):
    qs_yearly = [qs_rankings[uni][i] for uni in universities]
    the_yearly = [the_rankings[uni][i] for uni in universities]

    plt.plot(universities, qs_yearly, marker=markers_qs[i], linestyle='-', color=colors[i], label=f'QS {year}')
    plt.plot(universities, the_yearly, marker=markers_the[i], linestyle='--', color=colors[i], label=f'THE {year}', alpha=0.8)

plt.xlabel("Universities", fontsize=14, fontweight='bold')
plt.ylabel("Ranking Position (Lower is Better)", fontsize=14, fontweight='bold')
plt.title("Bangladeshi University Rankings in QS and THE (2023-2025)", fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better

# Adjust legend to the right-side within the chart area
plt.legend(fontsize=12, loc='center right', bbox_to_anchor=(1, 0.5), frameon=True)


# Add data labels for all years
for i, uni in enumerate(universities):
    for j, year in enumerate(years):
        plt.annotate(qs_rankings[uni][j], (uni, qs_rankings[uni][j]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=10)
        plt.annotate(the_rankings[uni][j], (uni, the_rankings[uni][j]), textcoords="offset points", xytext=(0,-15), ha='center', fontsize=10, color='red')

plt.tight_layout()  # Ensures everything fits well
plt.savefig("rankings_2023_2025.png", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Data for Bangladeshi University Rankings in QS and THE (2023-2025)
years = ["2023", "2024", "2025"]
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU", "DIU", "JUST"]

qs_rankings = {
    "DU": [1100, 1050, 1000], "BUET": [900, 850, 801], "NSU": [1150, 1100, 1001],
    "BRACU": [1300, 1250, 1201], "AIUB": [1350, 1300, 1201], "IUB": [1600, 1550, 1500],
    "JU": [1400, 1350, 1300], "CU": [1500, 1450, 1400], "RU": [1550, 1500, 1450],
    "KU": [1600, 1550, 1500], "DIU": [1700, 1650, 1600], "JUST": [1750, 1700, 1650]
}

the_rankings = {
    "DU": [1300, 1250, 1201], "BUET": [1100, 1050, 1001], "NSU": [1600, 1550, 1501],
    "BRACU": [1400, 1350, 1301], "AIUB": [1500, 1450, 1400], "IUB": [1700, 1650, 1600],
    "JU": [1450, 1400, 1350], "CU": [1550, 1500, 1450], "RU": [1600, 1550, 1500],
    "KU": [1700, 1650, 1600], "DIU": [1800, 1750, 1700], "JUST": [1850, 1800, 1750]
}

# Creating a DataFrame for better visualization
data = []
for uni in universities:
    for i, year in enumerate(years):
        data.append([year, uni, qs_rankings[uni][i], the_rankings[uni][i]])

df = pd.DataFrame(data, columns=["Year", "University", "QS Ranking", "THE Ranking"])
print(df)

# Creating a bar chart
x = np.arange(len(universities))  # Label locations
width = 0.25  # Bar width

fig, ax = plt.subplots(figsize=(14, 7))

# Plot bars for QS Rankings
for i, year in enumerate(years):
    ax.bar(x - width*(1-i), [qs_rankings[uni][i] for uni in universities], width, label=f'QS {year}')

# Plot bars for THE Rankings
for i, year in enumerate(years):
    ax.bar(x + width*(1-i), [the_rankings[uni][i] for uni in universities], width, label=f'THE {year}', alpha=0.7, hatch='//')

# Labels & Title
ax.set_xlabel("Universities", fontsize=14, fontweight='bold')
ax.set_ylabel("Ranking Position (Lower is Better)", fontsize=14, fontweight='bold')
ax.set_title("Bangladeshi University Rankings in QS and THE (2023-2025)", fontsize=16, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(universities, rotation=45, ha='right', fontsize=12)
ax.invert_yaxis()  # Invert y-axis since lower rank is better

# Adjust legend to the right-side blank space
ax.legend(fontsize=12, loc='center left', bbox_to_anchor=(1, 0.5), frameon=True)

plt.tight_layout()  # Ensures everything fits well
plt.savefig("bar11.png", bbox_inches='tight')
plt.show()
# Out:
#     Year University  QS Ranking  THE Ranking
# 0   2023         DU        1100         1300
# 1   2024         DU        1050         1250
# 2   2025         DU        1000         1201
# 3   2023       BUET         900         1100
# 4   2024       BUET         850         1050
# 5   2025       BUET         801         1001
# 6   2023        NSU        1150         1600
# 7   2024        NSU        1100         1550
# 8   2025        NSU        1001         1501
# 9   2023      BRACU        1300         1400
# 10  2024      BRACU        1250         1350
# 11  2025      BRACU        1201         1301
# 12  2023       AIUB        1350         1500
# 13  2024       AIUB        1300         1450
# 14  2025       AIUB        1201         1400
# 15  2023        IUB        1600         1700
# 16  2024        IUB        1550         1650
# 17  2025        IUB        1500         1600
# 18  2023         JU        1400         1450
# 19  2024         JU        1350         1400
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = ["2023", "2024", "2025"]
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU", "DIU", "JUST"]

qs_rankings = {
    "DU": [1100, 1050, 1000], "BUET": [900, 850, 801], "NSU": [1150, 1100, 1001],
    "BRACU": [1300, 1250, 1201], "AIUB": [1350, 1300, 1201], "IUB": [1600, 1550, 1500],
    "JU": [1400, 1350, 1300], "CU": [1500, 1450, 1400], "RU": [1550, 1500, 1450],
    "KU": [1600, 1550, 1500], "DIU": [1700, 1650, 1600], "JUST": [1750, 1700, 1650]
}

the_rankings = {
    "DU": [1300, 1250, 1201], "BUET": [1100, 1050, 1001], "NSU": [1600, 1550, 1501],
    "BRACU": [1400, 1350, 1301], "AIUB": [1500, 1450, 1400], "IUB": [1700, 1650, 1600],
    "JU": [1450, 1400, 1350], "CU": [1550, 1500, 1450], "RU": [1600, 1550, 1500],
    "KU": [1700, 1650, 1600], "DIU": [1800, 1750, 1700], "JUST": [1850, 1800, 1750]
}

# Set up figure and axis
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width
bar_width = 0.15
index = np.arange(len(universities))

# Define colors
colors_qs = ['b', 'royalblue', 'deepskyblue']
colors_the = ['g', 'limegreen', 'mediumseagreen']

# Plot bars for each year
for i, year in enumerate(years):
    ax.bar(index - bar_width * (1.5 - i), [qs_rankings[uni][i] for uni in universities], bar_width, label=f"QS {year}", color=colors_qs[i])
    ax.bar(index + bar_width * (i - 0.5), [the_rankings[uni][i] for uni in universities], bar_width, label=f"THE {year}", color=colors_the[i])

# Labels and title
ax.set_xlabel('Universities', fontsize=12)
ax.set_ylabel('Ranking (Lower is Better)', fontsize=12)
ax.set_title('University Rankings (QS vs THE, 2023-2025)', fontsize=14, fontweight='bold')
ax.set_xticks(index)
ax.set_xticklabels(universities, rotation=45, ha="right")

# Invert Y-axis (since lower rank numbers are better)
ax.invert_yaxis()

# Legend and layout adjustments
ax.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Show plot
plt.show()

# %%
# prompt: place the y axis 0 to upper from bottom to top

import matplotlib.pyplot as plt
import numpy as np
# ... (Your existing code)

# Plot rankings for all three years
plt.figure(figsize=(12, 7))

colors = ['b', 'g', 'm']  # Different colors for years
markers_qs = ['o', '^', 'D']  # Different markers for QS
markers_the = ['s', 'P', 'X']  # Different markers for THE

for i, year in enumerate(years):
    qs_yearly = [qs_rankings[uni][i] for uni in universities]
    the_yearly = [the_rankings[uni][i] for uni in universities]

    plt.plot(universities, qs_yearly, marker=markers_qs[i], linestyle='-', color=colors[i], label=f'QS {year}')
    plt.plot(universities, the_yearly, marker=markers_the[i], linestyle='--', color=colors[i], label=f'THE {year}', alpha=0.8)

plt.xlabel("Universities", fontsize=14, fontweight='bold')
plt.ylabel("Ranking Position (Lower is Better)", fontsize=14, fontweight='bold')
plt.title("Bangladeshi University Rankings in QS and THE (2023-2025)", fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=12)

# Set y-axis limits and ticks for better visualization (adjust as needed)
plt.ylim(1850, 700)  # Example: Set limits from 1850 to 700
plt.yticks(np.arange(700, 1900, 100)) # Example ticks every 100

plt.gca().invert_yaxis()  # Invert y-axis since lower rank is better

# Adjust legend to the right-side within the chart area
plt.legend(fontsize=12, loc='center right', bbox_to_anchor=(1, 0.5), frameon=True)

# ... (rest of your existing code)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = ["2023", "2024", "2025"]
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU", "DIU", "JUST"]

qs_rankings = {
    "DU": [1100, 1050, 1000], "BUET": [900, 850, 801], "NSU": [1150, 1100, 1001],
    "BRACU": [1300, 1250, 1201], "AIUB": [1350, 1300, 1201], "IUB": [1600, 1550, 1500],
    "JU": [1400, 1350, 1300], "CU": [1500, 1450, 1400], "RU": [1550, 1500, 1450],
    "KU": [1600, 1550, 1500], "DIU": [1700, 1650, 1600], "JUST": [1750, 1700, 1650]
}

the_rankings = {
    "DU": [1300, 1250, 1201], "BUET": [1100, 1050, 1001], "NSU": [1600, 1550, 1501],
    "BRACU": [1400, 1350, 1301], "AIUB": [1500, 1450, 1400], "IUB": [1700, 1650, 1600],
    "JU": [1450, 1400, 1350], "CU": [1550, 1500, 1450], "RU": [1600, 1550, 1500],
    "KU": [1700, 1650, 1600], "DIU": [1800, 1750, 1700], "JUST": [1850, 1800, 1750]
}

# Set up figure and axis
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width
bar_width = 0.15
index = np.arange(len(universities))

# Define colors
colors_qs = ['b', 'royalblue', 'deepskyblue']
colors_the = ['g', 'limegreen', 'mediumseagreen']

# Plot bars for each year
for i, year in enumerate(years):
    ax.bar(index - bar_width * (1.5 - i), [qs_rankings[uni][i] for uni in universities], bar_width, label=f"QS {year}", color=colors_qs[i])
    ax.bar(index + bar_width * (i - 0.5), [the_rankings[uni][i] for uni in universities], bar_width, label=f"THE {year}", color=colors_the[i])

# Labels and title
ax.set_xlabel('Universities', fontsize=12)
ax.set_ylabel('Ranking (Higher is Worse)', fontsize=12)
ax.set_title('University Rankings (QS vs THE, 2023-2025)', fontsize=14, fontweight='bold')
ax.set_xticks(index)
ax.set_xticklabels(universities, rotation=45, ha="right")

# Ensure y-axis starts at 0 and moves upward
ax.set_ylim(0, max(max(r) for r in qs_rankings.values()) + 100)

# Legend and layout adjustments
ax.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = ["2023", "2024", "2025"]
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU", "DIU", "JUST"]

qs_rankings = {
    "DU": [1100, 1050, 1000], "BUET": [900, 850, 801], "NSU": [1150, 1100, 1001],
    "BRACU": [1300, 1250, 1201], "AIUB": [1350, 1300, 1201], "IUB": [1600, 1550, 1500],
    "JU": [1400, 1350, 1300], "CU": [1500, 1450, 1400], "RU": [1550, 1500, 1450],
    "KU": [1600, 1550, 1500], "DIU": [1700, 1650, 1600], "JUST": [1750, 1700, 1650]
}

the_rankings = {
    "DU": [1300, 1250, 1201], "BUET": [1100, 1050, 1001], "NSU": [1600, 1550, 1501],
    "BRACU": [1400, 1350, 1301], "AIUB": [1500, 1450, 1400], "IUB": [1700, 1650, 1600],
    "JU": [1450, 1400, 1350], "CU": [1550, 1500, 1450], "RU": [1600, 1550, 1500],
    "KU": [1700, 1650, 1600], "DIU": [1800, 1750, 1700], "JUST": [1850, 1800, 1750]
}

# Set up figure and axis
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width
bar_width = 0.15
index = np.arange(len(universities))

# Define colors for QS and THE rankings
colors_qs = ['#DE0044', '#9EB7DA', '#5C8CC2']
colors_the = ['#FF5733', '#A0D468', '#2E8B57']

# Plot bars for each year
for i, year in enumerate(years):
    ax.bar(index - bar_width * (1.5 - i), [qs_rankings[uni][i] for uni in universities], bar_width,
           label=f"QS {year}", color=colors_qs[i])
    ax.bar(index + bar_width * (i - 0.5), [the_rankings[uni][i] for uni in universities], bar_width,
           label=f"THE {year}", color=colors_the[i])

# Labels and title
ax.set_xlabel('Universities', fontsize=12)
ax.set_ylabel('Ranking (Higher is Worse)', fontsize=12)
ax.set_title('University Rankings (QS vs THE, 2023-2025)', fontsize=14, fontweight='bold')
ax.set_xticks(index)
ax.set_xticklabels(universities, rotation=45, ha="right")

# Ensure y-axis starts at 0 and moves upward
ax.set_ylim(0, max(max(r) for r in qs_rankings.values()) + 100)

# Legend and layout adjustments
ax.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
years = ["2023", "2024", "2025"]
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU", "DIU", "JUST"]

qs_rankings = {
    "DU": [1100, 1050, 1000], "BUET": [900, 850, 801], "NSU": [1150, 1100, 1001],
    "BRACU": [1300, 1250, 1201], "AIUB": [1350, 1300, 1201], "IUB": [1600, 1550, 1500],
    "JU": [1400, 1350, 1300], "CU": [1500, 1450, 1400], "RU": [1550, 1500, 1450],
    "KU": [1600, 1550, 1500], "DIU": [1700, 1650, 1600], "JUST": [1750, 1700, 1650]
}

the_rankings = {
    "DU": [1300, 1250, 1201], "BUET": [1100, 1050, 1001], "NSU": [1600, 1550, 1501],
    "BRACU": [1400, 1350, 1301], "AIUB": [1500, 1450, 1400], "IUB": [1700, 1650, 1600],
    "JU": [1450, 1400, 1350], "CU": [1550, 1500, 1450], "RU": [1600, 1550, 1500],
    "KU": [1700, 1650, 1600], "DIU": [1800, 1750, 1700], "JUST": [1850, 1800, 1750]
}

# Calculate the average rankings
qs_avg = {uni: np.mean(qs_rankings[uni]) for uni in universities}
the_avg = {uni: np.mean(the_rankings[uni]) for uni in universities}

# Set up figure and axis
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width
bar_width = 0.15
index = np.arange(len(universities))

# Define colors for each year
colors = {
    "2023": "#DE0044",  # Red
    "2024": "#9EB7DA",  # Light Blue
    "2025": "#5C8CC2",  # Dark Blue
    "Average": "#000000"  # Black for average
}

# Plot bars for QS and THE rankings for each year
for i, year in enumerate(years):
    ax.bar(index - bar_width * (2 - i), [qs_rankings[uni][i] for uni in universities], bar_width, label=f"QS {year}", color=colors[year])
    ax.bar(index + bar_width * (i - 1), [the_rankings[uni][i] for uni in universities], bar_width, label=f"THE {year}", color=colors[year])

# Plot average rankings as a separate bar
ax.bar(index - bar_width * 2.5, [qs_avg[uni] for uni in universities], bar_width, label="QS Avg", color=colors["Average"], hatch="///", edgecolor="white")
ax.bar(index + bar_width * 2.5, [the_avg[uni] for uni in universities], bar_width, label="THE Avg", color=colors["Average"], hatch="\\\\\\", edgecolor="white")

# Labels and title
ax.set_xlabel('Universities', fontsize=12)
ax.set_ylabel('Ranking (Lower is Better)', fontsize=12)
ax.set_title('University Rankings (QS vs THE, 2023-2025) with Averages', fontsize=14, fontweight='bold')
ax.set_xticks(index)
ax.set_xticklabels(universities, rotation=45, ha="right")

# Ensure y-axis starts at 0 and moves upward
ax.set_ylim(0, max(max(r) for r in qs_rankings.values()) + 100)

# Legend and layout adjustments
ax.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU", "DIU", "JUST"]

qs_rankings = {
    "DU": [1100, 1050, 1000], "BUET": [900, 850, 801], "NSU": [1150, 1100, 1001],
    "BRACU": [1300, 1250, 1201], "AIUB": [1350, 1300, 1201], "IUB": [1600, 1550, 1500],
    "JU": [1400, 1350, 1300], "CU": [1500, 1450, 1400], "RU": [1550, 1500, 1450],
    "KU": [1600, 1550, 1500], "DIU": [1700, 1650, 1600], "JUST": [1750, 1700, 1650]
}

the_rankings = {
    "DU": [1300, 1250, 1201], "BUET": [1100, 1050, 1001], "NSU": [1600, 1550, 1501],
    "BRACU": [1400, 1350, 1301], "AIUB": [1500, 1450, 1400], "IUB": [1700, 1650, 1600],
    "JU": [1450, 1400, 1350], "CU": [1550, 1500, 1450], "RU": [1600, 1550, 1500],
    "KU": [1700, 1650, 1600], "DIU": [1800, 1750, 1700], "JUST": [1850, 1800, 1750]
}

# Calculate the average rankings
qs_avg = {uni: np.mean(qs_rankings[uni]) for uni in universities}
the_avg = {uni: np.mean(the_rankings[uni]) for uni in universities}

# Set up figure and axis
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width
bar_width = 0.4
index = np.arange(len(universities))

# Plot average rankings as separate bars
ax.bar(index - bar_width / 2, [qs_avg[uni] for uni in universities], bar_width,
       label="QS Average", color="#000000", hatch="///", edgecolor="white")

ax.bar(index + bar_width / 2, [the_avg[uni] for uni in universities], bar_width,
       label="THE Average", color="#000000", hatch="\\\\", edgecolor="white")

# Labels and title
ax.set_xlabel('Universities', fontsize=12)
ax.set_ylabel('Ranking (Lower is Better)', fontsize=12)
ax.set_title('Average University Rankings (QS vs THE, 2023-2025)', fontsize=14, fontweight='bold')
ax.set_xticks(index)
ax.set_xticklabels(universities, rotation=45, ha="right")

# Ensure y-axis starts at 0 and moves upward
ax.set_ylim(0, max(max(qs_avg.values()), max(the_avg.values())) + 100)

# Legend and layout adjustments
ax.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU", "DIU", "JUST"]

qs_rankings = {
    "DU": [1100, 1050, 1000], "BUET": [900, 850, 801], "NSU": [1150, 1100, 1001],
    "BRACU": [1300, 1250, 1201], "AIUB": [1350, 1300, 1201], "IUB": [1600, 1550, 1500],
    "JU": [1400, 1350, 1300], "CU": [1500, 1450, 1400], "RU": [1550, 1500, 1450],
    "KU": [1600, 1550, 1500], "DIU": [1700, 1650, 1600], "JUST": [1750, 1700, 1650]
}

the_rankings = {
    "DU": [1300, 1250, 1201], "BUET": [1100, 1050, 1001], "NSU": [1600, 1550, 1501],
    "BRACU": [1400, 1350, 1301], "AIUB": [1500, 1450, 1400], "IUB": [1700, 1650, 1600],
    "JU": [1450, 1400, 1350], "CU": [1550, 1500, 1450], "RU": [1600, 1550, 1500],
    "KU": [1700, 1650, 1600], "DIU": [1800, 1750, 1700], "JUST": [1850, 1800, 1750]
}

# Calculate the average rankings
qs_avg = {uni: np.mean(qs_rankings[uni]) for uni in universities}
the_avg = {uni: np.mean(the_rankings[uni]) for uni in universities}

# Set up figure and axis
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width
bar_width = 0.4
index = np.arange(len(universities))

# Plot average rankings
ax.bar(index - bar_width / 2, [qs_avg[uni] for uni in universities], bar_width,
       label="QS Average", color="#DE0044")

ax.bar(index + bar_width / 2, [the_avg[uni] for uni in universities], bar_width,
       label="THE Average", color="#5C8CC2")

# Labels and title
ax.set_xlabel('Universities', fontsize=12)
ax.set_ylabel('Ranking (Lower is Better)', fontsize=12)
ax.set_title('Average University Rankings (QS vs THE, 2023-2025)', fontsize=14, fontweight='bold')
ax.set_xticks(index)
ax.set_xticklabels(universities, rotation=45, ha="right")

# Ensure y-axis starts at 0 and moves upward
ax.set_ylim(0, max(max(qs_avg.values()), max(the_avg.values())) + 100)

# Legend and layout adjustments
ax.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
universities = ["DU", "BUET", "NSU", "BRACU", "AIUB", "IUB", "JU", "CU", "RU", "KU", "DIU", "JUST"]

qs_rankings = {
    "DU": [1100, 1050, 1000], "BUET": [900, 850, 801], "NSU": [1150, 1100, 1001],
    "BRACU": [1300, 1250, 1201], "AIUB": [1350, 1300, 1201], "IUB": [1600, 1550, 1500],
    "JU": [1400, 1350, 1300], "CU": [1500, 1450, 1400], "RU": [1550, 1500, 1450],
    "KU": [1600, 1550, 1500], "DIU": [1700, 1650, 1600], "JUST": [1750, 1700, 1650]
}

the_rankings = {
    "DU": [1300, 1250, 1201], "BUET": [1100, 1050, 1001], "NSU": [1600, 1550, 1501],
    "BRACU": [1400, 1350, 1301], "AIUB": [1500, 1450, 1400], "IUB": [1700, 1650, 1600],
    "JU": [1450, 1400, 1350], "CU": [1550, 1500, 1450], "RU": [1600, 1550, 1500],
    "KU": [1700, 1650, 1600], "DIU": [1800, 1750, 1700], "JUST": [1850, 1800, 1750]
}

# Calculate the average rankings
qs_avg = {uni: np.mean(qs_rankings[uni]) for uni in universities}
the_avg = {uni: np.mean(the_rankings[uni]) for uni in universities}

# Set up figure and axis
fig, ax = plt.subplots(figsize=(14, 8))

# Bar width
bar_width = 0.4
index = np.arange(len(universities))

# Plot average rankings
ax.bar(index - bar_width / 2, [qs_avg[uni] for uni in universities], bar_width,
       label="QS Average", color="#9EB7DA")  # Light Blue

ax.bar(index + bar_width / 2, [the_avg[uni] for uni in universities], bar_width,
       label="THE Average", color="#5C8CC2")  # Dark Blue

# Labels and title
ax.set_xlabel('Universities', fontsize=12)
ax.set_ylabel('Ranking (Lower is Better)', fontsize=12)
ax.set_title('Average University Rankings (QS vs THE, 2023-2025)', fontsize=14, fontweight='bold')
ax.set_xticks(index)
ax.set_xticklabels(universities, rotation=45, ha="right")

# Ensure y-axis starts at 0 and moves upward
ax.set_ylim(0, max(max(qs_avg.values()), max(the_avg.values())) + 100)

# Legend and layout adjustments
ax.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Show plot
plt.savefig("average_rankings.png", dpi=300)
plt.show()
