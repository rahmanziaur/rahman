# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmanziaur/rahman/blob/master/Test_Caliper_benchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.interpolate import make_interp_spline, BSpline
 
df = pd.read_csv('throughput.csv')
df1 = pd.read_csv('latency.csv')

#fig, ax = plt.subplots(nrows=1, ncols=3)

fig, ax = plt.subplots(constrained_layout=True)
x = df['Nodes']
y = df['Throughput']

xnew = np.linspace(x.min(), x.max(), 300) 
spl = make_interp_spline(x, y, k=3)  # type: BSpline
power_smooth = spl(xnew)

#plt.plot(xnew, power_smooth)

ax.plot(xnew, power_smooth, color='tab:red', label='Throughput')

ax.axis([0, 34, 800, 1400])

#ax.set_xlabel('angle [degrees]')
#ax.set_ylabel('signal')
#ax.set_title('Sine wave')
#ax.legend()

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis
x1 = df1['Nodes']
y1 = df1['Latency']



color = '#3399FF'
#ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1

xnew1 = np.linspace(x.min(), x.max(), 300) 
spl1 = make_interp_spline(x1, y1, k=3)  # type: BSpline
power_smooth1 = spl1(xnew1)

ax2.plot(xnew1, power_smooth1, color=color, label='Latency')
ax2.tick_params(axis='y')

ax2.axis([0, 34, 0, 100])

#ax2.tick_params(axis='x', labelcolor=color)
#ax2.legend()

ax3 = ax.twiny()  # instantiate a second axes that shares the same x-axis

color = 'tab:green'
#ax3.set_xlabel('sin22', color=color)  # we already handled the x-label with ax1
#ax3.plot(x1, y1, color=color)
#ax2.tick_params(axis='y', labelcolor=color)
ax3.tick_params(axis='x')


# figure = plt.gca()
# x_axis = figure.axes.get_xaxis()
# x_axis.set_visible(False)



figure = plt.gca()

figure.axes.xaxis.set_ticklabels([])


#fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

#rects1 = plt.plot(x, read_tp, label='Read', color='#3399FF')

# Data
# df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })
 
# # multiple line plot
# plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
# plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
# plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
# plt.legend()
#plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.interpolate import make_interp_spline, BSpline
 
df = pd.read_csv('throughput.csv')
df1 = pd.read_csv('latency.csv')

fig, ax = plt.subplots(nrows=1,ncols=2)
x = df['Nodes']
y = df['Throughput']

xnew = np.linspace(x.min(), x.max(), 300) 
spl = make_interp_spline(x, y, k=3)  # type: BSpline
power_smooth = spl(xnew)

ax[0].plot(xnew, power_smooth, color='tab:red', label='Throughput')
ax[0].legend(loc='upper right', bbox_to_anchor=(0.95, 0.98))

ax[0].axis([0, 34, 800, 1400])

ax2 = ax[0].twinx() 
x1 = df1['Nodes']
y1 = df1['Latency']

color = '#3399FF'

xnew1 = np.linspace(x.min(), x.max(), 300) 
spl1 = make_interp_spline(x1, y1, k=3) 
power_smooth1 = spl1(xnew1)

ax2.plot(xnew1, power_smooth1, color=color, label='Latency')
ax2.legend(loc='upper right', bbox_to_anchor=(0.897, 0.88))
ax2.tick_params(axis='y')
ax2.axis([0, 34, 0, 100])

ax3 = ax[0].twiny() 
ax3.tick_params(axis='x')
# ax2.grid(True)
# ax3.grid(True)
# ax.grid(True)

width = 0.35

rects1 = ax[1].bar(x - width/2, y, width, label='Read', color='#3399FF')
figure = plt.gca()
figure.axes.xaxis.set_ticklabels([])

fig.tight_layout()
plt.savefig('f7.pdf')
plt.show()

# %%
from scipy import linspace
from scipy import pi,sqrt,exp
from scipy.special import erf

from pylab import plot,show

def pdf(x):
    return 1/sqrt(2*pi) * exp(-x**2/2)

def cdf(x):
    return (1 + erf(x/sqrt(2))) / 2

def skew(x,e=0,w=1,a=0):
    t = (x-e) / w
    return 2 / w * pdf(t) * cdf(a*t)
    # You can of course use the scipy.stats.norm versions
    # return 2 * norm.pdf(t) * norm.cdf(a*t)


n = 2**10

e = 1.0 # location
w = 2.0 # scale

x = linspace(-10,10,n) 

for a in range(-3,4):
    p = skew(x,e,w,a)
    plot(x,p)

show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: DeprecationWarning: scipy.linspace is deprecated and will be removed in SciPy 2.0.0, use numpy.linspace instead
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: scipy.exp is deprecated and will be removed in SciPy 2.0.0, use numpy.exp instead
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


domain =  np.linspace(-1, 1, 100000)

ax = np.arange(1,33,1)
#print(ax, len(ax))

ay = np.arange(1325, 100, -39)


plt.plot(norm.pdf(domain, 0, 1))
plt.plot(norm.pdf(domain, 0, 2))
#plt.axis([-5, 5, None, None])
plt.show()
#plt.plot(ax,ay)
#print(ay, len(ay))

# %%
# R
# x = seq(-20, 20, by=.1)
# y = dnorm(x, mean=5.0, sd = 1.0)
# plot(x,y,main="normal Distribution", col="blue")

import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt

sigma_values = [0.5, 1.0, 2.0]
linestyles = ['-', '--', ':']
mu = 0.5
x = np.linspace(-10, 10, 1000)

#------------------------------------------------------------
# plot the distributions
fig, ax = plt.subplots(figsize=(5, 3.75))

for sigma, ls in zip(sigma_values, linestyles):
    # create a gaussian / normal distribution
    dist = norm(mu, sigma)

    plt.plot(x, dist.pdf(x), ls=ls, c='black',
             label=r'$\mu=%i,\ \sigma=%.1f$' % (mu, sigma))

plt.xlim(-5, 5)
plt.ylim(0, 0.85)

plt.xlabel('$x$')
plt.ylabel(r'$p(x|\mu,\sigma)$')
plt.title('Gaussian Distribution')

plt.legend()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-cd31fd07fa8e> in <module>()
# ----> 1 x = seq(-20, 20, by=.1)
#       2 y = dnorm(x, mean=5.0, sd = 1.0)
#       3 plot(x,y,main="normal Distribution", col="blue")
#
# NameError: name 'seq' is not defined
